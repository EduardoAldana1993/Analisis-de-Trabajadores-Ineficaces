# %% [markdown]
# Hola **Jose**!
#
# Soy **Patricio Requena** 👋. Es un placer ser el revisor de tu proyecto el día de hoy!
#
# Revisaré tu proyecto detenidamente con el objetivo de ayudarte a mejorar y perfeccionar tus habilidades. Durante mi revisión, identificaré áreas donde puedas hacer mejoras en tu código, señalando específicamente qué y cómo podrías ajustar para optimizar el rendimiento y la claridad de tu proyecto. Además, es importante para mí destacar los aspectos que has manejado excepcionalmente bien. Reconocer tus fortalezas te ayudará a entender qué
#
# técnicas y métodos están funcionando a tu favor y cómo puedes aplicarlos en futuras tareas.
#
# _**Recuerda que al final de este notebook encontrarás un comentario general de mi parte**_, empecemos!
#
# Encontrarás mis comentarios dentro de cajas verdes, amarillas o rojas, ⚠️ **por favor, no muevas, modifiques o borres mis comentarios** ⚠️:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
#
#
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>

# %% [markdown]
# # Proyecto Final: Telecomunicaciones, identificar operadores ineficaces, Red CallMeMaybe

# %% [markdown]
# ## Introduccion:

# %% [markdown]
# En el siguiente proyecto se hara la busqueda a los operadores mas ineficaces para poder mejorar el rendimiento o poder hacer un procesos de training. En el momento de encontrar las fallas se podra ver las areas de opotunidad que se poseen. Ademas, evaluar las opciones que tendrian los supervisores sobre este tipo de trabajadores. El objetivo del proyecto es analizar el desempeño de los operadores para identificar cuáles presentan indicadores de ineficiencia. Esto permitirá detectar oportunidades de mejora, optimizar recursos y proponer acciones basadas en evidencia. El proyecto se hara para la empresa CallMeMaybe y los datos fueron extraidos de la pagina "https://coding-bootcamps.notion.site/Proyecto-Final-Telecomunicaciones-identificar-operadores-ineficaces-fe835b92fcd446fca90d7c587c84b384".
#
# Se estaran utilizando los data sets **"telecom_dataset_us.csv"**, **"telecom_clients_us.csv"**, los cuales consisten en:
#
# El dataset comprimido `telecom_dataset_us.csv` contiene las siguientes columnas:
#
# - `user_id`: ID de la cuenta de cliente
# - `date`: fecha en la que se recuperaron las estadísticas
# - `direction`: "dirección" de llamada (`out` para saliente, `in` para entrante)
# - `internal`: si la llamada fue interna (entre los operadores de un cliente o clienta)
# - `operator_id`: identificador del operador
# - `is_missed_call`: si fue una llamada perdida
# - `calls_count`: número de llamadas
# - `call_duration`: duración de la llamada (sin incluir el tiempo de espera)
# - `total_call_duration`: duración de la llamada (incluido el tiempo de espera)
#
# El conjunto de datos `telecom_clients_us.csv` tiene las siguientes columnas:
#
# - `user_id`: ID de usuario/a
# - `tariff_plan`: tarifa actual de la clientela
# - `date_start`: fecha de registro de la clientela
#
# Utilizando asi los datos necesarios para poder realizarlo. En el siguiente resumen veremos los pasos que estaremos siguiendo para poder evaluar y argumentar nuestro futuro trabajo.

# %% [markdown]
# ## Objetivos:

# %% [markdown]
# - **Objetivo Principal:** Determinar qué operadores pueden considerarse ineficientes con base en métricas cuantitativas y validar si existen diferencias significativas entre operadores eficientes e ineficientes.
# - **Objetivos Secundarios:**
#   1. Encontrar opciones para su mejora.
#   2. Preparar y limpiar los datos para un análisis confiable.
#   6. Explorar el comportamiento de las métricas principales.
#   7. Definir criterios claros de eficiencia.
#   8. Realizar pruebas estadísticas que validen diferencias entre grupos.
#   9. Generar conclusiones basadas en evidencia.

# %% [markdown]
# ## Hipotesis:

# %% [markdown]
# **H0 (Hipótesis nula):**
#
# Los operadores tienen la misma tasa de llamadas perdidas.
# No hay evidencia de que alguien sea ineficaz.
#
# **H1 (Hipótesis alternativa):**
#
# Hay operadores cuya tasa de llamadas perdidas es significativamente mayor al promedio.
# Esos operadores son ineficaces.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
# Parece que hay una confusión con lo que se intenta comunicar en el archivo informativo. Tu proyecto final tiene varias etapas, cada etapa debe ser presentada en proyectos diferentes aquí en la plataforma.
#
# Para esta primera presentación deberías redactar sólo la descomposición de tareas para tu proyecto final del análisis de operadores, no es necesario aún código pero si hay que ser detallado en los pasos y secciones a desarrollar.
#
# Deberías cubrir al menos los siguientes puntos en tu descomposición de tareas y en la presentación final:
#
# - **Contexto y objetivos**: Siempre es importante dejar claro desde un inicio lo que se hará y para qué se hará
#
# - **Preprocesamiento de datos**: Es una parte escencial en tu proyecto y lo tienes bastante bien cubierto, felicidades!
#
# - **Análisis exploratorio**: Recuerda que debes cubrir esta parte también para entender los datos con los que trabajas, te recomendaría incluir la revisión de datos atípicos que luego puedan llegar a causar alguna métrica errónea al final de tu proyecto. También se debe redactar siempre la interpretación de cada gráfica mostrada para dejar un proceso de análisis más claro.
#
# - **Criterios de eficiencia claros**: Para determinar que es lo que hace un operador eficiente o no se deben establecer ciertos criterios que deben quedar muy bien explicados en el notebook
#
# - **Prueba de hipótesis**: Determinar si se tiene una diferencia significativa en nuestra métrica objetivo es importante por lo que hiciste muy bien al incluirla, recuerda comparar entre operadores eficientes y no eficientes con pruebas estadísticas
#
# - **Conclusiones y recomendaciones**: Una parte importante para culminar el proyecto ya que es donde se resume todos los hallazgos del análisis
#
# Si tienes dudas recuerda que puedes contactar a tu tutor o Success Manager para que puedan ayudarte a resolverlas.
#
# Saludos!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante: Muy buenas tardes;
# Si, la verdad me dejo bastente confundido porque crei que solo era la primera parte segun la guia. Espero que esta vez si este de manera correcta. Hable con una tutora, me aconsejo describir bien cada paso y borrar la programacion que habia hecho.</b> <a class=“tocSkip”></a>
# </div>

# %% [markdown]
# ## Paso 1: Procesamiento de Datos

# %% [markdown]
# En el Procesamiento de datos veremos los dos data sets. Los formatos de cada uno de los elementos que tenemos para poder hacer un analisis mas correcto sobre los trabajadores ineficaces. En este paso veremos y haremos verificaciones como las siguientes:
#
# 1. **Duplicados:** Nos aseguraremos que no tenemos datos duplicados que puedan afectar a nuestro data set.
# 2. **Incompletos o Nulos:** Esto nos asegurara de tener datos que se han desaparecido o que no sean utiles.
# 3. **Corrección de outliers evidentes por errores de captura:** Valores negativos imposibles. Métricas extremadamente fuera de rango por fallos en el sistema.
# 4. **Creación de métricas derivadas necesarias:** Tasa de eficiencia, tasa de pérdida, tiempo en llamada, etc.
# 5. **Normalización o escalamiento:** Para facilitar comparaciones entre operadores.

# %% [markdown]
# ## Paso 2: Encontrar a los trabajadores mas ineficientes, Analisis exploratorio de Data

# %% [markdown]
# Asimismo, pasaremos al analisis exploratorio de los datos (EDA), para que tengamos un mejor analisis. El análisis exploratorio permitirá entender patrones, variabilidad y comportamientos atípicos. Ademas tendremos varias tareas como las que veremos acontinuacion:
#
# 1. **Distribución de las métricas principales:** Histogramas, boxplots, violines. Ademas, de la identificación de datos atípicos que podrían sesgar/nublar el análisis.
# 2. **Comparación visual entre operadores:** Promedios por operador. Rangos y dispersión.
# 3. **Correlaciones entre variables:** Mapa de calor para detectar relaciones relevantes.
# 4. **Interpretación de cada gráfica:** Explicar qué muestran las distribuciones. Indicar si existen patrones relevantes (por ejemplo: operadores con tasas anormales). Señalar si hay evidencia preliminar de ineficiencia.
#
# Se establecerán criterios cuantitativos claros que permitan clasificar operadores como eficientes o ineficientes.
# Estos criterios deben ser objetivos, replicables y justificados.

# %% [markdown]
# ## Paso 3: Graficos para Analisis & Comprobacion de Hipotesis

# %% [markdown]
# Apesar de que ya hayamos visto historigramas en el punto anterior en este se vera mas afondo solo los trabajadores ineficaces y tambien probaremos las hipotesis establecidas con anterioridad. El propósito es comprobar si las diferencias entre operadores eficientes e ineficientes son estadísticamente significativas.
#
# Para este punto realizaremos los siguientes objetivos:
#
# **Definir la métrica objetivo:** Que en este caso ya tenemos basado en el data set, tiempos de espera, llamadas perdidas, pocas llamadas salientes.
#
# **Seleccionar la prueba adecuada:** Mann-Whitney U si los datos no son normales. t-test si se cumple normalidad (La cual es la mas probable de usar en este tipo de circunstancias).
#
# **Formular hipótesis:** Aplicar la hipotesis ya establecida.
#
# **Interpretación de resultados:** Significancia estadística. Qué implica para la eficiencia del operador y que otros datos podremos agregar.

# %% [markdown]
# ## Conclusiones & Recomendaciones:

# %% [markdown]
# Al finalizar el análisis (en la etapa final del proyecto), se redactarán conclusiones basadas en: Hallazgos generales del EDA. Operadores identificados como ineficientes. Métricas donde existe mayor problema. Resultados de las pruebas estadísticas. Implicaciones operativas para la empresa. Además, se elaborarán recomendaciones, como:
#
# - Capacitación específica.
# - Revisión de procedimientos.
# - Redistribución de carga.
# - Seguimiento periódico a operadores críticos.
#
# Se usaran tambien ejemplos y estudios de otras compañias con servicios similares. Ademas, se hara unos dashboards para tener visualizaciones mas claras y sensillas de utilizar usando tableau public.

# %% [markdown]
# ## Referencias

# %% [markdown]
# Aqui estaran todas las referencias sobre los estudios y ejemplos de compañias con servicios similares.

# %% [markdown]
# ## Glosario:

# %% [markdown]
# En este punto estara el glosario actualizado de los terminos para el trabajo, se actualizara de ser necesario. Adicional se expondra uno en estos momentos.
#
# **1. Análisis exploratorio de datos (EDA)**
#
# Proceso inicial del análisis donde se examina el comportamiento de las variables mediante visualizaciones y estadísticas descriptivas. Sirve para identificar patrones, outliers y relaciones entre variables.
#
# **2. Atípicos / Outliers**
#
# Datos que se encuentran muy alejados del comportamiento normal del conjunto. Pueden indicar errores de captura o situaciones excepcionales que requieren análisis.
#
# **3. Criterios de eficiencia**
#
# Reglas cuantitativas definidas para clasificar a un operador como eficiente o ineficiente. Pueden basarse en percentiles, umbrales o métricas del negocio.
#
# **4. Dataset**
#
# Conjunto de datos estructurado, generalmente en formato tabla, que contiene la información a analizar en el proyecto.
#
# **5. Hipótesis nula (H0)**
#
# Planteamiento estadístico que afirma que no existe diferencia entre dos grupos o condiciones (ejemplo: operadores eficientes e ineficientes).
#
# **6. Hipótesis alternativa (H1)**
#
# Planteamiento contrario a la hipótesis nula. Afirma que sí existe una diferencia significativa entre los grupos analizados.
#
# **7. Imputación**
#
# Método para reemplazar valores faltantes en un dataset usando medias, medianas u otros criterios.
#
# **8. Interpretación**
#
# Explicación de lo que muestran las gráficas o resultados del análisis, traduciendo lo visual/numérico en conclusiones entendibles.
#
# **9. Mann-Whitney U**
#
# Prueba estadística no paramétrica usada para comparar dos grupos cuando los datos no siguen una distribución normal.
#
# **10. Métrica**
#
# Valor numérico que mide algún aspecto del desempeño de un operador, como tasa de pérdida, velocidad, productividad o resolución.
#
# **11. Normalización**
#
# Proceso para ajustar valores numéricos a un mismo rango o escala con el fin de facilitar comparaciones.
#
# **12. Operador ineficiente**
#
# Operador que, según los criterios definidos, presenta un desempeño inferior al esperado o por debajo de los umbrales establecidos.
#
# **13. Preprocesamiento**
#
# Etapa de limpieza y preparación del dataset antes de hacer análisis. Incluye manejo de nulos, corrección de errores y creación de nuevas métricas.
#
# **14. Prueba estadística**
#
# Método utilizado para determinar si una diferencia entre grupos es significativa o se debe al azar.
#
# **15. Prueba t (t-test)**
#
# Prueba estadística paramétrica que compara medias entre dos grupos cuando los datos siguen distribución normal.
#
# **16. Segmentación**
#
# Proceso de dividir a los operadores en grupos (por ejemplo, eficientes vs. ineficientes) según criterios definidos.
#
# **17. Significancia estadística**
#
# Indica si un resultado es suficientemente fuerte como para rechazar la hipótesis nula. Se evalúa con el valor p.
#
# **18. Valor p**
#
# Probabilidad de obtener un resultado igual o más extremo que el observado si la hipótesis nula fuera verdadera. Si p es menor a un umbral (por ejemplo, 0.05), se considera significativo.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class="tocSkip"></a>
#
# Correcto, ahora tienes un plan bastante bien estructurado con lo que ya puedes avanzar.
#
# No olvides realizar la presentación en la última parte de tu proyecto (Empresa callme maybe) con los hallazgos del proyecto y para facilitar la revisión de la presentación procura exportarlo a PDF y aquí debes compartir y explicar tus hallazgos en tu proyecto final.
#
# Saludos!
